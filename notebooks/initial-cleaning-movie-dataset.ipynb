# %%
import pandas as pd
import seaborn as sns

# %%
movie = pd.read_csv('C:/Users/vasco/Ironhack/labs/Week7/Project/TMDB_movie_dataset_v11.csv')

# %%
movie.shape
# Out:
# (1140900, 24)

# %%
movie.head(10)
# Out:
#        id                    title  vote_average  vote_count    status  \
# 0   27205                Inception         8.364       34495  Released
# 1  157336             Interstellar         8.417       32571  Released
# 2     155          The Dark Knight         8.512       30619  Released
# 3   19995                   Avatar         7.573       29815  Released
# 4   24428             The Avengers         7.710       29166  Released
# 5  293660                 Deadpool         7.606       28894  Released
# 6  299536   Avengers: Infinity War         8.255       27713  Released
# 7     550               Fight Club         8.438       27238  Released
# 8  118340  Guardians of the Galaxy         7.906       26638  Released
# 9     680             Pulp Fiction         8.488       25893  Released
#
#   release_date     revenue  runtime  adult                     backdrop_path  \
# 0   2010-07-15   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg
# ...

# %%
movie.isnull().sum()
# Out:
# id                            0
# title                        13
# vote_average                  0
# vote_count                    0
# status                        0
# release_date             188648
# revenue                       0
# runtime                       0
# adult                         0
# backdrop_path            838406
# budget                        0
# homepage                1020159
# imdb_id                  537126
# original_language             0
# original_title               13
# overview                 232328
# popularity                    0
# poster_path              360814
# tagline                  981009
# genres                   457892
# production_companies     626522
# production_countries     506308
# spoken_languages         486993
# keywords                 832324
# dtype: int64

# %%
movie['release_date'] = pd.to_datetime(movie['release_date'], errors='coerce')


filtered_movies = movie[movie['release_date'] >= '2004-01-01']

# %%
filtered_movies.shape
# Out:
# (597573, 24)

# %%
filtered_movies = filtered_movies[filtered_movies['title'].notna()]

# %%
filtered_movies = filtered_movies[filtered_movies['release_date'].notna()]

# %%
filtered_movies= filtered_movies.drop(columns=['homepage'])
filtered_movies= filtered_movies.drop(columns=['backdrop_path'])
filtered_movies= filtered_movies.drop(columns=['imdb_id'])

# %%
filtered_movies.isnull().sum()
# Out:
# id                           0
# title                        0
# vote_average                 0
# vote_count                   0
# status                       0
# release_date                 0
# revenue                      0
# runtime                      0
# adult                        0
# budget                       0
# original_language            0
# original_title               0
# overview                 63570
# popularity                   0
# poster_path              64955
# tagline                 320707
# genres                  124903
# production_companies    192103
# production_countries    151373
# spoken_languages        138720
# keywords                266622
# dtype: int64

# %%
filtered_movies_new = filtered_movies[(filtered_movies['revenue'] != 0) & (filtered_movies['revenue'] >= 1000000)]

# %%
filtered_movies_new.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
filtered_movies_new.shape
# Out:
# (6606, 24)
